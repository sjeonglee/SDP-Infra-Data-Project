# %% [markdown]
# ## [python] 연관규칙분석(ASSOCIATION RULE ANALYSIS) - 장바구니분석
# ### 개요
# 추천 시스템이란, '특정 시점'에 '특정 고객'이 좋아할 만한 리스트를 추려내는 것이다. 추천 시스템을 구현하는 데는 다음과 같은 세 가지 데이터를 활용한다 - 1) 고객의 정보, 2) 가지고 있는 전체 리스트(아이템), 3) 시스템 외부 정보가 그것이다.
#
# 많은 추천 시스템의 알고리즘이 있지만, 인프라 추천을 위해 다음과 같은 장점을 가진 Association Rule Analysis(연관규칙분석)을 활용하였다.
# 1) Association Rule Analysis은 cold-start problem을 풀기에 좋다. 즉, non-personalized 알고리즘으로 고객에 대한 정보가 없을 경우 좋은 선택이다.
# 2) Association Rule Analysis는 연산량이 적음에도 불구하고 비교적 좋은 성능을 낸다.
#
# 따라서, 인프라 딜 하나 하나를 발생한 구매라고 생각하고, 각종 지표(국가, 인프라 금액)를 구매한 아이템이라고 가정하여 연관규칙분석을 실시하였다.
#
# ### Reference:
# https://hezzong.tistory.com/entry/python-%EC%97%B0%EA%B4%80%EA%B7%9C%EC%B9%99%EB%B6%84%EC%84%9DA-Priori-Algorithm
# https://yamalab.tistory.com/67

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# The duplicated ProjectIDs were deleted before loading the excel file
data = pd.read_excel('PPIDB_2019_final (BF) final.xlsx', sheet_name='Base')
data.head()
# Out:
#                             Region    Country          IncomeGroup IDAStatus  \
# 0  Latin America and the Caribbean     Mexico  Upper middle income   Non-IDA
# 1  Latin America and the Caribbean  Argentina  Upper middle income   Non-IDA
# 2  Latin America and the Caribbean  Argentina  Upper middle income   Non-IDA
# 3  Latin America and the Caribbean  Argentina  Upper middle income   Non-IDA
# 4  Latin America and the Caribbean  Argentina  Upper middle income   Non-IDA
#
#    Financialclosureyear FinancialclosureMonth  ProjectID  \
# 0                  1990              November        991
# 1                  1990             September       1330
# 2                  1990             September       1329
# 3                  1990             September       1331
# 4                  1990             September       3179
#
#                            Projectname  \
# 0         Telefonos de Mexico (Telmex)
# 1  Intercity Roads - Corridor 7, 8 & 9
# 2         Intercity Roads - Corridor 6
# 3        Intercity Roads - Corridor 10
# 4           Camino del Atlantico SA CV
#
#                                         RelatedNames    TypeofPPI  ...  \
# 0                                             Telmex  Divestiture  ...
# 1                              Servicios Viales S.A.   Brownfield  ...
# 2  Concessionario Vial Corridor Route 188 UTE - C...   Brownfield  ...
# 3                                    Covicentro S.A.   Brownfield  ...
# 4  Vial interconection system of Atlantic region,...   Brownfield  ...
#
#   incomelevel      incomelevelname lendingtype lendingtypename           GDP  \
# 0         UMC  Upper middle income         IBD            IBRD  2.612536e+11
# 1         HIC          High income         IBD            IBRD  1.413524e+11
# 2         HIC          High income         IBD            IBRD  1.413524e+11
# 3         HIC          High income         IBD            IBRD  1.413524e+11
# 4         HIC          High income         IBD            IBRD  1.413524e+11
#
#    population   CPI2019 realinvestment realphysicalassets realfeestogovernment
# 0  83943132.0  1.921853    4001.298828           0.000000          4001.298828
# 1  32618651.0  1.921853     340.168060         340.168060             0.000000
# 2  32618651.0  1.921853      82.639694          82.639694             0.000000
# 3  32618651.0  1.921853     186.419785         186.419785             0.000000
# 4  32618651.0  1.921853            NaN           0.000000             0.000000
#
# [5 rows x 73 columns]

# %%
# check columns
data.columns
# Out:
# Index(['Region', 'Country', 'IncomeGroup', 'IDAStatus', 'Financialclosureyear',
#        'FinancialclosureMonth', 'ProjectID', 'Projectname', 'RelatedNames',
#        'TypeofPPI', 'SubtypeofPPI', 'Projectstatus', 'dateStatusUpdated',
#        'Primarysector', 'SubSector', 'Segment', 'Location', 'ContractPeriod',
#        'GovtGrantingContract', 'DirectGovtSupport', 'DirectGovtSupportValue',
#        'InDirectGovtSupport', 'InDirectGovtSupportValue', 'InvestmentYear',
#        'PercentPrivate', 'FeesToGovernment', 'PhysicalAssets',
#        'TotalInvestment', 'CapacityType', 'Capacity', 'Technology',
#        'RelatedProjects', 'BidCriteria', 'AwardMethod', 'NumberOfBids',
#        'Sponsors', 'MainRevenueSource', 'OtherRevenueSource',
#        'MultiLateralSupport', 'BiLateralSupport', 'Description', 'FundingYear',
#        'TotalDebtFunding', 'DebtEquityGrantRatio', 'TotalEquity',
#        'ProjectBanks', 'CommercialDebt', 'MultilateralDebt', 'BilateralDebt',
#        'InstitutionalDebt', 'PublicDebt', 'InternationalDebt', 'LocalDebt',
#        'UnsolicitedProposal', 'PublicDisclosure', 'DescriptionOfSource',
#        'bordercountries', 'shareborder', 'countrycode', 'region', 'regionname',
#        'adminregion', 'adminregionname', 'incomelevel', 'incomelevelname',
#        'lendingtype', 'lendingtypename', 'GDP', 'population', 'CPI2019',
#        'realinvestment', 'realphysicalassets', 'realfeestogovernment'],
#       dtype='object')

# %%
# put out some columns that are not meaningful
# 사람이 판단하기는 어렵지만, 애초에 의미가 없는 것들 (Unique Project ID 등) 및 연속 데이터 삭제
# ProjectID'(This would be the index)
col = ['Region', 'Country', 'IncomeGroup', 'IDAStatus', 'TypeofPPI', 'SubtypeofPPI', 'Projectstatus',
       'Primarysector', 'SubSector', 'Segment']

# %%
data.set_index('ProjectID', inplace=True)
data_cut = data[col]
data_cut.dropna()
data_cut.head()
# Out:
#                                     Region    Country          IncomeGroup  \
# ProjectID
# 991        Latin America and the Caribbean     Mexico  Upper middle income
# 1330       Latin America and the Caribbean  Argentina  Upper middle income
# 1329       Latin America and the Caribbean  Argentina  Upper middle income
# 1331       Latin America and the Caribbean  Argentina  Upper middle income
# 3179       Latin America and the Caribbean  Argentina  Upper middle income
#
#           IDAStatus    TypeofPPI                         SubtypeofPPI  \
# ProjectID
# 991         Non-IDA  Divestiture                                 Full
# 1330        Non-IDA   Brownfield  Rehabilitate, operate, and transfer
# 1329        Non-IDA   Brownfield  Rehabilitate, operate, and transfer
# 1331        Non-IDA   Brownfield  Rehabilitate, operate, and transfer
# 3179        Non-IDA   Brownfield  Rehabilitate, operate, and transfer
#
#           Projectstatus Primarysector     SubSector  Segment
# ProjectID
# 991              Active           ICT  ICT backbone    Other
# 1330          Concluded     Transport         Roads  Highway
# 1329          Concluded     Transport         Roads  Highway
# 1331          Concluded     Transport         Roads  Highway
# 3179          Concluded     Transport         Roads  Highway

# %%
dataset = []
for i in range(0, len(data_cut)):
    ele = data_cut.iloc[i].tolist()
    dataset.append(ele)

# %%
dataset
# Out:
# [['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Peru',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Railways, Roads',
#   'Fixed assets and passenger, <br/>Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Middle East and North Africa',
#   'Yemen, Rep.',
#   'Low income',
#   'IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Philippines',
#   'Lower middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Turkey',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Sub-Saharan Africa',
#   'South Africa',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'Kiribati',
#   'Lower middle income',
#   'IDA',
#   'Divestiture',
#   'Partial',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Guatemala',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Bridge and highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Sub-Saharan Africa',
#   "Cote d'Ivoire",
#   'Lower middle income',
#   'IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Sub-Saharan Africa',
#   'Madagascar',
#   'Low income',
#   'IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Airports',
#   'Runway and terminal'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Philippines',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Airports',
#   'Runway and terminal'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Sub-Saharan Africa',
#   'Guinea-Bissau',
#   'Low income',
#   'IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Guyana',
#   'Upper middle income',
#   'IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['Latin America and the Caribbean',
#   'Venezuela, RB',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Sub-Saharan Africa',
#   'Central African Republic',
#   'Low income',
#   'IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Cancelled',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility without sewerage'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Sub-Saharan Africa',
#   'South Africa',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['South Asia',
#   'Pakistan',
#   'Lower middle income',
#   'Blended',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution and transmission'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Treatment plant',
#   'Potable water treatment plant'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Ukraine',
#   'Lower middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['Latin America and the Caribbean',
#   'Costa Rica',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Water and sewerage',
#   'Treatment plant',
#   'Sewerage treatment plant'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Sub-Saharan Africa',
#   'Nigeria',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Merchant',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['South Asia',
#   'Pakistan',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'Cambodia',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Costa Rica',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Electricity',
#   'Electricity distribution and generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Channel dredging and terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Concluded',
#   'Water and sewerage',
#   'Treatment plant',
#   'Sewerage treatment plant'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['Middle East and North Africa',
#   'Egypt, Arab Rep.',
#   'Lower middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Concluded',
#   'Water and sewerage',
#   'Water Utility',
#   'Sewerage collection and treatment'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Ecuador',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Uzbekistan',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Merchant',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas transmission'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas distribution'],
#  ['East Asia and Pacific',
#   'Cambodia',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Merchant',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Sub-Saharan Africa',
#   'Sudan',
#   'Lower middle income',
#   'IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Natural Gas',
#   'Natural gas transmission'],
#  ['East Asia and Pacific',
#   'Vanuatu',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Philippines',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Belize',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Distressed',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Treatment plant',
#   'Potable water treatment plant'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Cancelled',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution and generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Lao PDR',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Roads',
#   'Bridge'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and passenger'],
#  ['Sub-Saharan Africa',
#   'Gambia, The',
#   'Low income',
#   'IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Cancelled',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility without sewerage'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Middle East and North Africa',
#   'Algeria',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Bulgaria',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Distressed',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'Sri Lanka',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Channel dredging and terminal'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Sub-Saharan Africa',
#   'Tanzania',
#   'Low income',
#   'IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
# ...
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['South Asia',
#   'Pakistan',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Brazil',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Airports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Bridge'],
#  ['Latin America and the Caribbean',
#   'Bolivia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Cancelled',
#   'Transport',
#   'Airports',
#   'Runway and terminal'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Bridge'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Brazil',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Concluded',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['East Asia and Pacific',
#   'Vietnam',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'Pakistan',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Sub-Saharan Africa',
#   'Mozambique',
#   'Low income',
#   'IDA',
#   'Management and lease contract',
#   'Lease contract',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Sub-Saharan Africa',
#   'Ghana',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Turkey',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'Pakistan',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Vietnam',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Peru',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Guatemala',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Sub-Saharan Africa',
#   'Kenya',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Peru',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Bridge'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Costa Rica',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Guatemala',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Concluded',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Albania',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Latin America and the Caribbean',
#   'Bolivia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Railways',
#   'Fixed assets, freight and passenger'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Natural Gas',
#   'Natural gas transmission'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Sub-Saharan Africa',
#   'Madagascar',
#   'Low income',
#   'IDA',
#   'Greenfield project',
#   'Merchant',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Sub-Saharan Africa',
#   'Tanzania',
#   'Low income',
#   'IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Thailand',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['South Asia',
#   'India',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Mexico',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Cancelled',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Latin America and the Caribbean',
#   'Ecuador',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Nicaragua',
#   'Lower middle income',
#   'IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Roads',
#   'Highway'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, lease or rent, and transfer',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility with sewerage'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity distribution'],
#  ['Latin America and the Caribbean',
#   'Brazil',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Rehabilitate, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Transport',
#   'Railways',
#   'Fixed assets and freight'],
#  ['Latin America and the Caribbean',
#   'Brazil',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['East Asia and Pacific',
#   'Malaysia',
#   'Upper middle income',
#   'Non-IDA',
#   'Management and lease contract',
#   'Management contract',
#   'Active',
#   'Water and sewerage',
#   'Water Utility',
#   'Water utility without sewerage'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Partial',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Latin America and the Caribbean',
#   'Colombia',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Russian Federation',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Merchant',
#   'Active',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Kazakhstan',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'China',
#   'Upper middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Cancelled',
#   'Water and sewerage',
#   'Treatment plant',
#   'Potable water treatment plant'],
#  ['Latin America and the Caribbean',
#   'Argentina',
#   'Upper middle income',
#   'Non-IDA',
#   'Brownfield',
#   'Build, rehabilitate, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity distribution, generation, and transmission'],
#  ['East Asia and Pacific',
#   'Philippines',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Concluded',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['East Asia and Pacific',
#   'Indonesia',
#   'Lower middle income',
#   'Non-IDA',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ['Europe and Central Asia',
#   'Moldova',
#   'Lower middle income',
#   'Blended',
#   'Greenfield project',
#   'Build, operate, and transfer',
#   'Active',
#   'Transport',
#   'Ports',
#   'Terminal'],
#  ['Sub-Saharan Africa',
#   'Tanzania',
#   'Low income',
#   'IDA',
#   'Greenfield project',
#   'Build, own, and operate',
#   'Concluded',
#   'ICT',
#   'ICT backbone',
#   'Other'],
#  ['Europe and Central Asia',
#   'Kazakhstan',
#   'Upper middle income',
#   'Non-IDA',
#   'Divestiture',
#   'Full',
#   'Cancelled',
#   'Energy',
#   'Electricity',
#   'Electricity generation'],
#  ...]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

"""
주어진 코드에서 fit 함수를 통해 dataset은 고유한 라벨을 갖게 되고,
transform함수를 통해서 파이썬 리스트를 one-hot 인코딩 된 numPy 배열로 변환합니다.
one-hot 인코딩에 대한 자세한 설명을 원하시면 다음 글을 참고해 주시기 바랍니다.
(https://teddylee777.github.io/machine-learning/python-numpy%EB%A1%9C-one-hot-encoding-%EC%89%BD%EA%B2%8C%ED%95%98%EA%B8%B0)
"""
# Out:
# '\n주어진 코드에서 fit 함수를 통해 dataset은 고유한 라벨을 갖게 되고,\ntransform함수를 통해서 파이썬 리스트를 one-hot 인코딩 된 numPy 배열로 변환합니다.\none-hot 인코딩에 대한 자세한 설명을 원하시면 다음 글을 참고해 주시기 바랍니다.\n(https://teddylee777.github.io/machine-learning/python-numpy%EB%A1%9C-one-hot-encoding-%EC%89%BD%EA%B2%8C%ED%95%98%EA%B8%B0)\n'

# %%
# 지지도가 0.5 이상인 항목들
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                                itemsets
# 0   0.931726                                (Active)
# 1   0.509605                                (Energy)
# 2   0.643338                    (Greenfield project)
# 3   0.899914                               (Non-IDA)
# 4   0.687018                   (Upper middle income)
# 5   0.618622            (Greenfield project, Active)
# 6   0.843999                       (Non-IDA, Active)
# 7   0.643950           (Upper middle income, Active)
# 8   0.573718           (Greenfield project, Non-IDA)
# 9   0.684204          (Upper middle income, Non-IDA)
# 10  0.553530   (Greenfield project, Non-IDA, Active)
# 11  0.641625  (Upper middle income, Non-IDA, Active)

# %%
# antecedents: 조건절 / consequents: 결과절
association_rules(frequent_itemsets, metric="lift", min_threshold=1)
# Out:
#                        antecedents                     consequents  \
# 0             (Greenfield project)                        (Active)
# 1                         (Active)            (Greenfield project)
# 2                        (Non-IDA)                        (Active)
# 3                         (Active)                       (Non-IDA)
# 4            (Upper middle income)                        (Active)
# 5                         (Active)           (Upper middle income)
# 6            (Upper middle income)                       (Non-IDA)
# 7                        (Non-IDA)           (Upper middle income)
# 8    (Greenfield project, Non-IDA)                        (Active)
# 9                (Non-IDA, Active)            (Greenfield project)
# 10            (Greenfield project)               (Non-IDA, Active)
# 11                        (Active)   (Greenfield project, Non-IDA)
# 12  (Upper middle income, Non-IDA)                        (Active)
# 13   (Upper middle income, Active)                       (Non-IDA)
# 14               (Non-IDA, Active)           (Upper middle income)
# 15           (Upper middle income)               (Non-IDA, Active)
# 16                       (Non-IDA)   (Upper middle income, Active)
# 17                        (Active)  (Upper middle income, Non-IDA)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.643338            0.931726  0.618622    0.961582  1.032044
# 1             0.931726            0.643338  0.618622    0.663953  1.032044
# 2             0.899914            0.931726  0.843999    0.937865  1.006589
# 3             0.931726            0.899914  0.843999    0.905844  1.006589
# 4             0.687018            0.931726  0.643950    0.937311  1.005994
# 5             0.931726            0.687018  0.643950    0.691136  1.005994
# 6             0.687018            0.899914  0.684204    0.995904  1.106665
# 7             0.899914            0.687018  0.684204    0.760299  1.106665
# 8             0.573718            0.931726  0.553530    0.964811  1.035509
# 9             0.843999            0.643338  0.553530    0.655842  1.019437
# 10            0.643338            0.843999  0.553530    0.860403  1.019437
# 11            0.931726            0.573718  0.553530    0.594091  1.035509
# 12            0.684204            0.931726  0.641625    0.937768  1.006485
# 13            0.643950            0.899914  0.641625    0.996390  1.107205
# 14            0.843999            0.687018  0.641625    0.760220  1.106550
# 15            0.687018            0.843999  0.641625    0.933927  1.106550
# 16            0.899914            0.643950  0.641625    0.712984  1.107205
# 17            0.931726            0.684204  0.641625    0.688641  1.006485
#
#     leverage  conviction
# 0   0.019207    1.777141
# 1   0.019207    1.061345
# 2   0.005525    1.098801
# 3   0.005525    1.062974
# 4   0.003837    1.089080
# 5   0.003837    1.013332
# 6   0.065947   24.433953
# 7   0.065947    1.305718
# 8   0.018981    1.940211
# 9   0.010554    1.036333
# 10  0.010554    1.117515
# 11  0.018981    1.050189
# 12  0.004134    1.097086
# 13  0.062125   27.723724
# 14  0.061782    1.305289
# 15  0.061782    2.361046
# 16  0.062125    1.240526
# 17  0.004134    1.014250

# %% [markdown]
# ## 결론
# #### 1. "조건절"을 좋아하는 사람은 "결과절"도 좋아하였다: 조건절에 맞는 프로젝트를 보는 경우, 결과절에 해당하는 프로젝트를 띄워줄 수 있겠음.
# #### 2. 국가와 다른 항목들의 연관관계는 위에서는 나타나지 않으나, 한 column당 element 종류가 확률에 영향을 주기 때문에 (국가의 수는 region의 수보다 많음) / 1에서 조건절과 결과절을 이용하여 See Also를 띄워줄 때 국가나 Region을 맞추어 띄워주는 것이 좋겠음.
# #### 3. 연속변수의 경우 범주형으로 변환하여 분석해보면 다른 재미있는 결과가 나올 것이라고 생각함
